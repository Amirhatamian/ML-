# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhatamian/ML-/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_excel('222.xlsx')

# %%
df.head()
# Out:
#         Nome   Cognome  Matricola  Anno Accademico Data Immatricolazione  \
# 0   Federico     CONTI  3115896.0           2324.0            2022-11-05
# 1   Federica   Bianchi  4986045.0           2324.0            2022-11-30
# 2      Alice     Russo  3072741.0           2324.0            2021-10-02
# 3  Francesca    Marino  1398354.0           2324.0            2021-12-07
# 4      luigi  Barbieri  2202787.0           2023.0            2022-06-14
#
#   Anno Corso Sede Scuola      Facoltà Residenza  Fascia Isee   Tasse  Sconto  \
# 0          1        Roma   Matematica    Milano          0.0  3500.0     NaN
# 1          1      Milano  Informatica   bologna          0.0  2300.0     NaN
# 2          2        Roma   Ingegneria   Venezia          1.0   680.0 -1020.0
# 3          2     Firenze   Matematica   bologna          1.0   880.0 -1320.0
# 4          1      Milano      Lettere   treviso          1.0  1520.0 -2280.0
#
#    Crediti Frequentati  Crediti Disponibili
# ...

# %%
df.describe()
# Out:
#           Matricola  Anno Accademico  Fascia Isee        Tasse       Sconto  \
# count  4.900000e+01        49.000000    49.000000    49.000000    47.000000
# mean   3.194822e+06      2299.346939     2.857143  2079.183673  -640.851064
# std    1.202867e+06        86.052443     1.457738  1085.341415   654.535447
# min    1.047677e+06      1920.000000     0.000000   660.000000 -2520.000000
# 25%    2.281251e+06      2324.000000     2.000000  1100.000000 -1070.000000
# 50%    3.363019e+06      2324.000000     3.000000  1980.000000  -540.000000
# 75%    4.321517e+06      2324.000000     4.000000  2800.000000     0.000000
# max    4.986045e+06      2324.000000     5.000000  4700.000000     0.000000
#
#        Crediti Frequentati  Crediti Disponibili
# count            50.000000            48.000000
# mean             41.340000            70.187500
# std              23.333964            20.411361
# min               0.000000             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nome                   49 non-null     object
#  1   Cognome                49 non-null     object
#  2   Matricola              49 non-null     float64
#  3   Anno Accademico        49 non-null     float64
#  4   Data Immatricolazione  50 non-null     datetime64[ns]
#  5   Anno Corso             50 non-null     object
#  6   Sede Scuola            50 non-null     object
#  7   Facoltà                50 non-null     object
#  8   Residenza              50 non-null     object
#  9   Fascia Isee            49 non-null     float64
#  10  Tasse                  49 non-null     float64
#  11  Sconto                 47 non-null     float64
#  12  Crediti Frequentati    50 non-null     int64
#  13  Crediti Disponibili    48 non-null     float64
# ...

# %%
 df['Residenza'].unique()
# Out:
# array(['Milano', 'bologna', 'Venezia', 'treviso', 'rome', 'Padova',
#        'Torino'], dtype=object)

# %%
df['Residenza'].count()
# Out:
# 50

# %%
torino_data = df[df['Residenza'].str.lower() == 'torino']

# %%
torino_data
# Out:
#         Nome  Cognome  Matricola  Anno Accademico Data Immatricolazione  \
# 12    Enrico  Ferrari  4525126.0           2324.0            2021-09-25
# 14       NaN      NaN        NaN              NaN            2023-01-20
# 16      sara    conti  2058904.0           2122.0            2021-12-01
# 33      Sara    Ricci  3363019.0           2324.0            2021-05-20
# 41     Mario  Moretti  1602947.0           2324.0            2020-12-21
# 46  Federica    rossi  4258034.0           2324.0            2021-05-15
#
#    Anno Corso Sede Scuola         Facoltà Residenza  Fascia Isee   Tasse  \
# 12          3      Milano      Statistica    Torino          2.0  1980.0
# 14          5      Milano        Economia    Torino          2.0   660.0
# 16          3        Roma        Economia    Torino          2.0   720.0
# 33          3     Palermo      Matematica    Torino          4.0  1800.0
# 41          4      Milano  Giurisprudenza    Torino          5.0  1400.0
# ...

# %%
df['Sede Scuola	'] = df['Sede Scuola'].str.capitalize()

# %%
df['Residenza'] = df['Residenza'].str.capitalize()

# %%
df['Cognome'] = df['Cognome'].str.capitalize()

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-16-bf934754a5b1>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(), inplace=True)
# <ipython-input-16-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.shape
# Out:
# (50, 15)
